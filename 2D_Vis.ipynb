# %% [markdown]
# <a href="https://colab.research.google.com/github/shehan28/MNIST-2D-Vis/blob/main/2D_Vis.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.datasets import fetch_openml


mnist = fetch_openml('mnist_784', version=1)
X, y = mnist.data, mnist.target.astype(int)


n_samples = 1000
X_subset = X[:n_samples]
y_subset = y[:n_samples]


pca = PCA(n_components=2)
X_reduced = pca.fit_transform(X_subset)


plt.figure(figsize=(10, 8))
scatter = plt.scatter(X_reduced[:, 0], X_reduced[:, 1], c=y_subset, cmap='viridis', alpha=0.5, edgecolor='k')


plt.legend(*scatter.legend_elements(), title="Classes")

plt.title('PCA of MNIST Dataset')
plt.xlabel('Principal Component 1')
plt.ylabel('Principal Component 2')
plt.grid()
plt.show()
